# %%
#tensorflow2.0手势识别
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
import h5py

# %%
def load_dataset():
    train_dataset = h5py.File(r'C:\Users\alex\Desktop\train_signs.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File(r'C:\Users\alex\Desktop\test_signs.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
train_set_x_ori,train_set_y_ori,test_set_x_ori,test_set_y_ori,classes = load_dataset()

# %%
print(train_set_x_ori.shape)
print(train_set_y_ori.shape)
print(train_set_y_ori)
print(classes)
# Out:
# (1080, 64, 64, 3)
# (1, 1080)
# [[5 0 2 ... 2 4 5]]
# [0 1 2 3 4 5]

# %%
print(np.max(train_set_x_ori))
print(np.min(train_set_x_ori))
# Out:
# 244
# 4

# %%
plt.figure()
plt.imshow(train_set_x_ori[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_set_x = train_set_x_ori/255

# %%
test_set_x = test_set_x_ori/255
test_set_y = test_set_y_ori.reshape(test_set_y_ori[0].shape,)

# %%
train_set_y = train_set_y_ori.reshape(1080,)
print(trian_set_y.shape)
# Out:
# (1080,)

# %%
print(test_set_y.shape)
# Out:
# (120,)

# %%
print(np.max(train_set_x))
# Out:
# 0.9568627450980393

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_set_x[i], cmap=plt.cm.binary)
plt.show()

# %%
print(train_set_x.shape)
print(train_set_y.shape)
print(train_set_y)
print(train_set_x.shape)
# Out:
# (1080, 64, 64, 3)
# (1080,)
# [5 0 2 ... 2 4 5]
# (1080, 64, 64, 3)

# %%
#设置模型
model = keras.Sequential([keras.layers.Flatten(input_shape=(64,64,3)),keras.layers.Dense(128,activation='relu'),keras.layers.Dense(6,activation='softmax')])

# %%
model.summary()
# Out:
# Model: "sequential_55"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_33 (Flatten)         (None, 12288)             0
# _________________________________________________________________
# dense_103 (Dense)            (None, 128)               1572992
# _________________________________________________________________
# dense_104 (Dense)            (None, 6)                 774
# =================================================================
# Total params: 1,573,766
# Trainable params: 1,573,766
# Non-trainable params: 0
# _________________________________________________________________

# %%
#进行预设值
model.compile(metrics=['accuracy'],loss='sparse_categorical_crossentropy',optimizer='adam')

# %%
model.fit(train_set_x,trian_set_y,batch_size=64,verbose=1,epochs=50)
# Out:
# Train on 1080 samples
# Epoch 1/50
# 1080/1080 [==============================] - 0s 458us/sample - loss: 7.6035 - accuracy: 0.1861
# Epoch 2/50
# Epoch 28/50
# 1080/1080 [==============================] - 0s 258us/sample - loss: 0.6395 - accuracy: 0.8065
# Epoch 29/50
# 1080/1080 [==============================] - 0s 235us/sample - loss: 0.5980 - accuracy: 0.8185
# Epoch 30/50
# 1080/1080 [==============================] - 0s 238us/sample - loss: 0.6812 - accuracy: 0.7750
# Epoch 31/50
# 1080/1080 [==============================] - 0s 272us/sample - loss: 0.6372 - accuracy: 0.7769
# Epoch 32/50
# 1080/1080 [==============================] - 0s 239us/sample - loss: 0.6399 - accuracy: 0.7833
# Epoch 33/50
# 1080/1080 [==============================] - 0s 235us/sample - loss: 0.6952 - accuracy: 0.7537
# Epoch 34/50
# 1080/1080 [==============================] - 0s 236us/sample - loss: 0.7190 - accuracy: 0.7481
# Epoch 35/50
# 1080/1080 [==============================] - 0s 228us/sample - loss: 0.6549 - accuracy: 0.7657
# Epoch 36/50
# 1080/1080 [==============================] - 0s 223us/sample - loss: 0.5888 - accuracy: 0.7981
# Epoch 37/50
# 1080/1080 [==============================] - 0s 234us/sample - loss: 0.5208 - accuracy: 0.8398
# Epoch 38/50
# 1080/1080 [==============================] - 0s 241us/sample - loss: 0.5609 - accuracy: 0.8056
# Epoch 39/50
# 1080/1080 [==============================] - 0s 235us/sample - loss: 0.6034 - accuracy: 0.7907
# Epoch 40/50
# 1080/1080 [==============================] - 0s 246us/sample - loss: 0.4923 - accuracy: 0.8639
# Epoch 41/50
# 1080/1080 [==============================] - 0s 237us/sample - loss: 0.4855 - accuracy: 0.8630
# Epoch 42/50
# 1080/1080 [==============================] - 0s 242us/sample - loss: 0.5142 - accuracy: 0.8269
# Epoch 43/50
# 1080/1080 [==============================] - 0s 235us/sample - loss: 0.5217 - accuracy: 0.8278
# Epoch 44/50
# 1080/1080 [==============================] - 0s 249us/sample - loss: 0.4992 - accuracy: 0.8556
# Epoch 45/50
# 1080/1080 [==============================] - 0s 252us/sample - loss: 0.4917 - accuracy: 0.8491
# Epoch 46/50
# 1080/1080 [==============================] - 0s 224us/sample - loss: 0.5041 - accuracy: 0.8426
# Epoch 47/50
# 1080/1080 [==============================] - 0s 228us/sample - loss: 0.4721 - accuracy: 0.8528
# Epoch 48/50
# 1080/1080 [==============================] - 0s 223us/sample - loss: 0.4875 - accuracy: 0.8380
# Epoch 49/50
# 1080/1080 [==============================] - 0s 222us/sample - loss: 0.4215 - accuracy: 0.8806
# Epoch 50/50
# 1080/1080 [==============================] - 0s 226us/sample - loss: 0.4190 - accuracy: 0.8750

# %%
model.evaluate(train_set_x,train_set_y,verbose=2)
model.evaluate(test_set_x,test_set_y,verbose=2)
# Out:
# 1080/1 - 0s - loss: 0.3646 - accuracy: 0.8722
# 120/1 - 0s - loss: 0.5894 - accuracy: 0.7667
# [0.6085254192352295, 0.76666665]
